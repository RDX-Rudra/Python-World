# %% [markdown]
# Web Scraping from internshala by RDX-Rudra

# %%
import requests
from bs4 import BeautifulSoup as bsp
import pandas as pd

# %%
requests.get('https://groww.in/stocks/user/explore', 'html.parser')
# Out:
# <Response [200]>

# %%
url='https://groww.in/stocks'

# %%
# resp = requests.get(url,'html.parser').content
# print(resp.status_code)

# %%
fieldname = "indian-railway-finance-corporation-ltd"

# %%
field=fieldname.replace(' ','-')

# %%
modified_url=url+'/'+str(field)+'?exchange=NSE'
print(f"Status :{requests.get(modified_url)}")
print(modified_url)
# Out:
# Status :<Response [200]>
# https://groww.in/stocks/indian-railway-finance-corporation-ltd?exchange=NSE

# %%
resp_new=requests.get(modified_url)

# %%
soup=bsp(resp_new.content,'html.parser')
#print(soup)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-theme="light" lang="en" style="color-scheme:light">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, minimum-scale=1" name="viewport"/>
#   <link href="/favicon32x32-groww.ico" rel="icon"/>
#   <title>
#    IRFC Share Price Today - IRFC Ltd Stock Price Live NSE/BSE
#   </title>
#   <meta content="IRFC Share Price - Get IRFC Ltd LIVE BSE/NSE stock price with Performance, Fundamentals, Market Cap, Share holding, financial report,
#     company profile, annual report, quarterly results, profit and loss" name="description"/>
#   <meta content="index" name="robots"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="https://groww.in/groww-logo-270.png" name="twitter:image"/>
#   <meta content="IRFC Share Price - Get IRFC Ltd LIVE BSE/NSE stock price with Performance, Fundamentals, Market Cap, Share holding, financial report,
# ...

# %%
name=soup.find_all('div',id='tv-chart-container')
print(len(name))
#print(name)
# Out:
# 0
