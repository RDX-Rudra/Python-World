# %% [markdown]
# # house pricing prediction

# %%
from pyexpat import model
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model


df = pd.read_csv("../homelook.csv")

# %matplotlib inline
plt.xlabel('area(sqr ft)', fontsize=20)
plt.ylabel('price(US$)', fontsize=20)
plt.scatter(df.area, df.price, color='red',marker='+')


model = linear_model.LinearRegression()
model.fit(df[['area']], df.price)

plt.plot(df.area, model.predict(df[['area']]), color='blue')
model.predict([[3300]])
# Out:
# /home/rudra/anaconda3/lib/python3.10/site-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
model.coef_
# Out:
# array([135.78767123])

# %%
model.intercept_
# Out:
# 180616.43835616432

# %%
y = 135.78767123 * 3300 + 180616.43835616432

# %%
model.predict([[5000]])
# Out:
# /home/rudra/anaconda3/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
print(y)
# Out:
# 628715.7534151643

# %%
d = pd.read_csv("areas.csv")
d
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   2500
# 4   3540
# 5   4120
# 6   4560
# 7   5490
# 8   6234
# 9   9000
# 10  8400
# 11  7100

# %%
p = model.predict(d)

# %%
d['prices'] = p
d
# Out:
#     area        prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   2500  5.200856e+05
# 4   3540  6.613048e+05
# 5   4120  7.400616e+05
# 6   4560  7.998082e+05
# 7   5490  9.260908e+05
# 8   6234  1.027117e+06
# 9   9000  1.402705e+06
# 10  8400  1.321233e+06
# 11  7100  1.144709e+06

# %%
d.to_csv("newprediction.csv", index=False)

# %%
import pickle

# %%
with open('model_homeprice', 'wb') as f:
    pickle.dump(model,f)

# %%
with open('model_homeprice','rb') as f:
    mp = pickle.load(f)

# %%
mp.predict([[5000]])
# Out:
# /home/rudra/anaconda3/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])
